# %% [markdown]
# <a href="https://colab.research.google.com/github/FCENA-PUCE/MetodosNumericos-05-N0062/blob/main/2-Notebooks/01-Fundamentos-y-biseccion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table style="border: none; border-collapse: collapse;">
#     <tr>
#         <td style="width: 20%; vertical-align: middle; padding-right: 10px;">
#             <img src="https://i.imgur.com/X5m8yDo.png" width="120">
#         </td>
#         <td style="width: 2px; text-align: center;">
#             <font color="#1957d1" size="7">|</font><br>
#             <font color="#1957d1" size="7">|</font>
#         </td>
#         <td>
#             <p style="font-variant: small-caps;"><font color="#1957d1" size="5">
#                 <b>Facultad de Ciencias Exactas, Naturales y Ambientales</b>
#             </font> </p>
#             <p style="font-variant: small-caps;"><font color="#1957d1" size="4">
#                 Métodos Numéricos &bull; Fundamentos y método de bisección
#             </font></p>
#             <p style="font-style: oblique;"><font color="#1957d1" size="3">
#                 Mario Cueva &bull; Andrés Merino &bull; Período 2026-1
#             </font></p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ---
# ## <font color='264CC7'> Introducción </font>
#
# Este cuaderno de trabajo permite practicar los conceptos del **Resumen no. 1: Fundamentos y método de bisección**.
#
# Al finalizar, se espera que puedas:
#
# - Identificar cifras significativas en distintos tipos de números.
# - Convertir números entre bases y reconocer el papel de la posición de cada dígito.
# - Calcular errores absoluto, relativo y aproximado.
# - Verificar las condiciones necesarias para aplicar bisección.
# - Implementar y usar el método de bisección para aproximar raíces.

# %% [markdown]
# Los paquetes necesarios son:

# %%
# Paquetes necesarios
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## <font color='264CC7'> 1. Cifras significativas </font>
#
# Las cifras significativas son los dígitos que aportan información sobre la precisión de una medida. Antes de automatizar el conteo, completa la siguiente tabla a mano.

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #264CC7; border-left: 5px solid #264CC7; padding: 0.5em;">
# <strong>Ejercicio 1:</strong><br>
# Para cada número, indica cuántas cifras significativas tiene y justifica brevemente tu respuesta.
# </div>
#
# | Número | Cifras significativas | Justificación |
# |---:|:---:|---|
# | 0.004560 |  |  |
# | 1000 |  |  |
# | 1.000e3 |  |  |
# | 20.030 |  |  |
# | 0.07010 |  |  |

# %% [markdown]
# ---
# ## <font color='264CC7'> 2. Sistema numérico </font>
#
# En un sistema posicional de base `b`, cada dígito se multiplica por una potencia de la base según su posición.

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #264CC7; border-left: 5px solid #264CC7; padding: 0.5em;">
# <strong>Ejercicio 2:</strong><br>
# Completa la función <code>entero_a_decimal</code>. Debe recibir un número escrito como texto y su base, y devolver su valor en decimal.
# </div>

# %%
def entero_a_decimal(numero, base):
    """Convierte un entero no negativo desde una base dada hacia decimal."""
    total = 0
    digitos = str(numero)

    # TODO: recorre los dígitos de derecha a izquierda.
    # Pista: el último dígito multiplica a base**0.

    return total

# Casos de prueba
print(entero_a_decimal('1011', 2))   # Esperado: 11
print(entero_a_decimal('343', 10))   # Esperado: 343
print(entero_a_decimal('1A', 16))    # Reto: esperado 26 si decides admitir A=10
# Out:
# 0
# 0
# 0

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #264CC7; border-left: 5px solid #264CC7; padding: 0.5em;">
# <strong>Ejercicio 3:</strong><br>
# Convierte los siguientes números a decimal usando la función anterior. Luego verifica con <code>int(numero, base)</code>.
# </div>

# %%
datos = [
    ('110101', 2),
    ('2024', 5),
    ('755', 8),
    ('2F', 16),
]

for numero, base in datos:
    # TODO: calcula la conversión con tu función.
    valor = None
    verificacion = int(numero, base)
    print(f'{numero}_{base} = {valor} ; verificación = {verificacion}')
# Out:
# 110101_2 = None ; verificación = 53
# 2024_5 = None ; verificación = 264
# 755_8 = None ; verificación = 493
# 2F_16 = None ; verificación = 47

# %% [markdown]
# ---
# ## <font color='264CC7'> 3. Representación de enteros con signo </font>
#
# Con `n` bits, el rango de enteros con signo es:
#
# $$
# -2^{n-1} \leq x \leq 2^{n-1}-1.
# $$

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #264CC7; border-left: 5px solid #264CC7; padding: 0.5em;">
# <strong>Ejercicio 4:</strong><br>
# Completa la función que calcula el rango de enteros con signo para una cantidad de bits.
# </div>

# %%
def rango_enteros_con_signo(n_bits):
    minimo = None  # TODO
    maximo = None  # TODO
    return minimo, maximo

for n in [8, 16, 32, 64]:
    print(n, rango_enteros_con_signo(n))
# Out:
# 8 (None, None)
# 16 (None, None)
# 32 (None, None)
# 64 (None, None)

# %% [markdown]
# ---
# ## <font color='264CC7'> 4. Errores </font>
#
# Si `x` es el valor verdadero y `x_aprox` es una aproximación, entonces:
#
# $$
# E_a = |x - \widehat{x}|,
# \qquad
# E_r = \frac{|x - \widehat{x}|}{|x|}.
# $$

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #264CC7; border-left: 5px solid #264CC7; padding: 0.5em;">
# <strong>Ejercicio 5:</strong><br>
# Completa las funciones para calcular error absoluto, error relativo y error relativo porcentual.
# </div>

# %%
def error_absoluto(x, x_aprox):
    return None  # TODO

def error_relativo(x, x_aprox):
    return None  # TODO

def error_relativo_porcentual(x, x_aprox):
    return None  # TODO

x = 3.1416
x_aprox = 3.14

print('Error absoluto:', error_absoluto(x, x_aprox))
print('Error relativo:', error_relativo(x, x_aprox))
print('Error relativo porcentual:', error_relativo_porcentual(x, x_aprox))
# Out:
# Error absoluto: None
# Error relativo: None
# Error relativo porcentual: None

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #264CC7; border-left: 5px solid #264CC7; padding: 0.5em;">
# <strong>Ejercicio 6:</strong><br>
# Calcula los errores para cada aproximación y ordena los casos desde la mejor hasta la peor aproximación según el error relativo porcentual.
# </div>

# %%
casos = pd.DataFrame({
    'valor_verdadero': [1000, 0.02, math.pi, math.sqrt(2)],
    'aproximacion': [999.99, 0.03, 3.1416, 1.41]
})

# TODO: agrega columnas para error absoluto y error relativo porcentual.

casos
# Out:
#    valor_verdadero  aproximacion
# 0      1000.000000      999.9900
# 1         0.020000        0.0300
# 2         3.141593        3.1416
# 3         1.414214        1.4100

# %% [markdown]
# Cuando no se conoce el valor verdadero, se puede comparar una aproximación con la aproximación anterior:
#
# $$
# E_{	ext{aprox}} = |x_i - x_{i-1}|.
# $$

# %%
aproximaciones = [1.5, 1.25, 1.375, 1.4375, 1.40625, 1.421875]

# TODO: construye una tabla con la aproximación actual, la anterior,
# el error aproximado y el error aproximado relativo porcentual.

tabla_aprox = pd.DataFrame()
tabla_aprox
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ---
# ## <font color='264CC7'> 5. Cambio de signo </font>
#
# Para aplicar bisección, la función debe ser continua en $[a,b]$ y debe cumplirse que:
#
# $$
# f(a)f(b)<0.
# $$

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #264CC7; border-left: 5px solid #264CC7; padding: 0.5em;">
# <strong>Ejercicio 7:</strong><br>
# Completa la función <code>hay_cambio_de_signo</code> y úsala para analizar los intervalos propuestos.
# </div>

# %%
def f(x):
    return x**2 - 2

def hay_cambio_de_signo(funcion, a, b):
    return None  # TODO

intervalos = [(0, 1), (1, 2), (2, 3), (-2, 0)]

for a, b in intervalos:
    print(f'[{a}, {b}] ->', hay_cambio_de_signo(f, a, b))
# Out:
# [0, 1] -> None
# [1, 2] -> None
# [2, 3] -> None
# [-2, 0] -> None

# %%
# Visualización de f(x) = x^2 - 2 en el intervalo [-2, 3]
x = np.linspace(-2, 3, 400)
y = f(x)

plt.axhline(0, color='black', linewidth=1)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Cambio de signo y raíces de f(x) = x^2 - 2')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ---
# ## <font color='264CC7'> 6. Método de bisección </font>
#
# El método de bisección divide el intervalo a la mitad y conserva el subintervalo donde se mantiene el cambio de signo.

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #264CC7; border-left: 5px solid #264CC7; padding: 0.5em;">
# <strong>Ejercicio 8:</strong><br>
# Realiza manualmente las primeras cinco iteraciones para <code>f(x)=x^2-2</code> en el intervalo <code>[1,2]</code>. Después completa el código para verificar tus resultados.
# </div>

# %%
def paso_biseccion(funcion, a, b):
    m = None  # TODO: punto medio

    # TODO: decide qué subintervalo conserva el cambio de signo.
    nuevo_a = None
    nuevo_b = None

    return nuevo_a, nuevo_b, m

a, b = 1, 2
filas = []

for i in range(1, 6):
    a, b, m = paso_biseccion(f, a, b)
    filas.append({
        'iteracion': i,
        'a': a,
        'b': b,
        'm': m,
        'f(m)': f(m) if m is not None else None,
        'semiancho': (b - a) / 2 if a is not None and b is not None else None,
    })

pd.DataFrame(filas)
# Out:
#    iteracion     a     b     m  f(m) semiancho
# 0          1  None  None  None  None      None
# 1          2  None  None  None  None      None
# 2          3  None  None  None  None      None
# 3          4  None  None  None  None      None
# 4          5  None  None  None  None      None

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #264CC7; border-left: 5px solid #264CC7; padding: 0.5em;">
# <strong>Ejercicio 9:</strong><br>
# Implementa el método completo de bisección. La función debe devolver una tabla con todas las iteraciones realizadas.
# </div>

# %%
def biseccion(funcion, a, b, tolerancia=1e-6, max_iter=100):
    if not hay_cambio_de_signo(funcion, a, b):
        raise ValueError('El intervalo no cumple la condición de cambio de signo.')

    filas = []
    m_anterior = None

    for i in range(1, max_iter + 1):
        # TODO: calcula m, f(a), f(b), f(m)
        m = None
        fa = None
        fb = None
        fm = None

        # TODO: calcula error aproximado si existe m_anterior.
        error_aprox = None

        filas.append({
            'iteracion': i,
            'a': a,
            'b': b,
            'm': m,
            'f(a)': fa,
            'f(b)': fb,
            'f(m)': fm,
            'error_aprox': error_aprox,
            'semiancho': (b - a) / 2,
        })

        # TODO: criterios de parada.
        # Puedes usar abs(fm) < tolerancia, error_aprox < tolerancia o semiancho < tolerancia.

        # TODO: actualiza el intervalo.

        m_anterior = m

    return pd.DataFrame(filas)

tabla = biseccion(f, 1, 2, tolerancia=1e-5, max_iter=50)
tabla.tail()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <module>
#      35         m_anterior = m
#      37     return pd.DataFrame(filas)
# ---> 39 tabla = biseccion(f, 1, 2, tolerancia=1e-5, max_iter=50)
#      40 tabla.tail()
#
# Input In [12], in biseccion(funcion, a, b, tolerancia, max_iter)
#       1 def biseccion(funcion, a, b, tolerancia=1e-6, max_iter=100):
#       2     if not hay_cambio_de_signo(funcion, a, b):
# ----> 3         raise ValueError('El intervalo no cumple la condición de cambio de signo.')
#       5     filas = []
#       6     m_anterior = None
#
# ValueError: El intervalo no cumple la condición de cambio de signo.

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #264CC7; border-left: 5px solid #264CC7; padding: 0.5em;">
# <strong>Ejercicio 10:</strong><br>
# Usa tu implementación para aproximar raíces de las siguientes funciones. Indica el intervalo, la aproximación final y el número de iteraciones.
# </div>

# %%
funciones = {
    'x^3 - x - 2': lambda x: x**3 - x - 2,
    'cos(x) - x': lambda x: math.cos(x) - x,
    'exp(-x) - x': lambda x: math.exp(-x) - x,
}

intervalos = {
    'x^3 - x - 2': (1, 2),
    'cos(x) - x': (0, 1),
    'exp(-x) - x': (0, 1),
}

resultados = []

for nombre, funcion in funciones.items():
    a, b = intervalos[nombre]
    # TODO: llama a biseccion y registra la última aproximación.
    raiz = None
    iteraciones = None
    resultados.append({
        'funcion': nombre,
        'intervalo': (a, b),
        'raiz_aproximada': raiz,
        'iteraciones': iteraciones,
    })

pd.DataFrame(resultados)

# %% [markdown]
# ---
# ## <font color='264CC7'> 7. Preguntas de cierre </font>
#
# Responde en tus propias palabras:
#
# 1. ¿Por qué un error absoluto pequeño no siempre significa una buena aproximación?
# 2. ¿Qué condición debe cumplir un intervalo para aplicar bisección?
# 3. ¿Qué puede ocurrir si no hay cambio de signo en el intervalo?
# 4. ¿Cuál criterio de parada te parece más claro para reportar resultados? ¿Por qué?
# 5. ¿Qué ventaja y qué desventaja tiene el método de bisección?

# %%
# Espacio para pruebas adicionales
